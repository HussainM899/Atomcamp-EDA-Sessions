# %% [markdown]
# # **EDA Session 2**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Uploading Data**

# %%
df = pd.read_csv("I:/My Drive/Data Science/Python Projects/Projects/Atomcamp Projects/Classwork/EDA/Data/WA_Fn-UseC_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### **Read Headers**

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df["JobSatisfaction"]
# Out:
# 0       4
# 1       2
# 2       3
# 3       3
# 4       2
#        ..
# 1465    4
# 1466    1
# 1467    2
# 1468    2
# 1469    3
# Name: JobSatisfaction, Length: 1470, dtype: int64

# %% [markdown]
# ### **Removing extra spaces and unwanted characters from start and end**

# %%
df.columns.str.strip()
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
s = pd.Series(['1. Bat.  ', '2. Dog!\n', '3. fox?\t', np.nan])
s
# Out:
# 0    1. Bat.
# 1    2. Dog!\n
# 2    3. fox?\t
# 3          NaN
# dtype: object

# %%
s.str.strip('123.!? \n\t')
# Out:
# 0    Bat
# 1    Dog
# 2    fox
# 3    NaN
# dtype: object

# %% [markdown]
# ### **Understanding Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Gives statistical details
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Describe boolean and object

df.describe(include="object")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
#Describe boolean and object

df.describe(include=["object", "bool"])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
#Show first 20 rows

df.head(20)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
#Show last 30 rows

df.tail(30)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1441   56        No         Non-Travel        667  Research & Development
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1443   42        No      Travel_Rarely        300  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1445   41        No      Travel_Rarely        582  Research & Development
# 1446   34        No      Travel_Rarely        704                   Sales
# 1447   36        No         Non-Travel        301                   Sales
# 1448   41        No      Travel_Rarely        930                   Sales
# 1449   32        No      Travel_Rarely        529  Research & Development
# 1450   35        No      Travel_Rarely       1146         Human Resources
# 1451   38        No      Travel_Rarely        345                   Sales
# ...

# %% [markdown]
# ### **Checking Duplicates**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
#Check number of duplicates

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### **Sorting**

# %%
df1 = df.sort_values(["DailyRate"], ascending=0)
df1.head(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 427    60        No  Travel_Frequently       1499                   Sales
# 986    39        No      Travel_Rarely       1498                   Sales
# 155    29        No         Non-Travel       1496  Research & Development
# 1056   28       Yes  Travel_Frequently       1496                   Sales
# 1202   38        No      Travel_Rarely       1495  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 427                 28          3         Marketing              1
# 986                 21          4     Life Sciences              1
# 155                  1          1  Technical Degree              1
# 1056                 1          3  Technical Degree              1
# 1202                 4          2           Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df_obj = df.select_dtypes(["object"])
df_obj
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %% [markdown]
# ### **Selecting object data type values in new variable**

# %%
df_int = df.select_dtypes(["int64"])
df_int
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %% [markdown]
# ### **Unique Values**

# %%
#Finding Unique value count in a column

df['Department'].nunique()
# Out:
# 3

# %%
#Finding Unique value in a column

df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
#Finding Unique value in a column

df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
#For all the unique values in all columns

for column in df:
    print("Column", column, ",Unique values are", df[column].nunique())
    print(df[column].unique())
    print("----------------------------------")
# Out:
# Column Age ,Unique values are 43
# [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# ----------------------------------
# Column Attrition ,Unique values are 2
# ['Yes' 'No']
# ----------------------------------
# Column BusinessTravel ,Unique values are 3
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ----------------------------------
# Column DailyRate ,Unique values are 886
# [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %% [markdown]
# ### **Missing Value**

# %%
df.isnull() #Check for missing values
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
df["Attrition"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Attrition, Length: 1470, dtype: bool

# %%
for column in df:
    print("Columns:", column, " missing values", df[column].isnull().sum())
    print("---------------------------------------------")
# Out:
# Columns: Age  missing values 0
# ---------------------------------------------
# Columns: Attrition  missing values 0
# ---------------------------------------------
# Columns: BusinessTravel  missing values 0
# ---------------------------------------------
# Columns: DailyRate  missing values 0
# ---------------------------------------------
# Columns: Department  missing values 0
# ---------------------------------------------
# Columns: DistanceFromHome  missing values 0
# ---------------------------------------------
# Columns: Education  missing values 0
# ---------------------------------------------
# Columns: EducationField  missing values 0
# ---------------------------------------------
# Columns: EmployeeCount  missing values 0
# ---------------------------------------------
# Columns: EmployeeNumber  missing values 0
# ---------------------------------------------
# Columns: EnvironmentSatisfaction  missing values 0
# ---------------------------------------------
# ...

# %%
def data(data):
    print("------------Column---------------")
    print(df.columns)
    print("------------info---------------")
    print(df.info())
    print("------------Shape---------------")
    print(df.shape)
    print("------------Duplicate---------------")
    print(df.duplicated())
    print("------------Column Types---------------")
    print(df.dtypes)
    print("------------Missing values sum---------------")
    print(df.isnull().sum())
    print("------------End---------------")

# %%
data(df)
# Out:
# ------------Column---------------
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
# ------------info---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ...

# %% [markdown]
# ### **Group By**

# %%
df.groupby(['WorkLifeBalance']).mean(numeric_only =True)
# Out:
#                        Age   DailyRate  DistanceFromHome  Education  \
# WorkLifeBalance
# 1                37.287500  812.100000          9.425000   2.975000
# 2                37.188953  827.459302          9.325581   2.857558
# 3                36.849944  798.409854          9.277716   2.927212
# 4                36.568627  765.098039          8.274510   2.921569
#
#                  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# WorkLifeBalance
# 1                          1.0     1014.237500                 2.650000
# 2                          1.0     1026.511628                 2.671512
# 3                          1.0     1019.240761                 2.744681
# 4                          1.0     1059.549020                 2.738562
#
#                  HourlyRate  JobInvolvement  JobLevel  ...  PerformanceRating  \
# WorkLifeBalance                                        ...
# 1                 63.800000        2.737500  1.875000  ...           3.175000
# ...

# %%
df.groupby(['WorkLifeBalance']).mean(numeric_only=True)
# Out:
#                        Age   DailyRate  DistanceFromHome  Education  \
# WorkLifeBalance
# 1                37.287500  812.100000          9.425000   2.975000
# 2                37.188953  827.459302          9.325581   2.857558
# 3                36.849944  798.409854          9.277716   2.927212
# 4                36.568627  765.098039          8.274510   2.921569
#
#                  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# WorkLifeBalance
# 1                          1.0     1014.237500                 2.650000
# 2                          1.0     1026.511628                 2.671512
# 3                          1.0     1019.240761                 2.744681
# 4                          1.0     1059.549020                 2.738562
#
#                  HourlyRate  JobInvolvement  JobLevel  ...  PerformanceRating  \
# WorkLifeBalance                                        ...
# 1                 63.800000        2.737500  1.875000  ...           3.175000
# ...

# %%
df.groupby(['WorkLifeBalance']).median(numeric_only=True)
# Out:
#                   Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# WorkLifeBalance
# 1                35.5      762.0               7.0        3.0            1.0
# 2                35.5      824.0               7.0        3.0            1.0
# 3                36.0      805.0               7.0        3.0            1.0
# 4                35.0      703.0               5.0        3.0            1.0
#
#                  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# WorkLifeBalance
# 1                         990.0                      3.0        61.5
# 2                        1045.5                      3.0        67.0
# 3                        1009.0                      3.0        66.0
# 4                        1106.0                      3.0        64.0
#
#                  JobInvolvement  JobLevel  ...  PerformanceRating  \
# WorkLifeBalance                            ...
# 1                           3.0       2.0  ...                3.0
# ...

# %%
#Group by specific column and take mean of hourly rate

df.groupby(['EducationField'])[["HourlyRate", "Age"]].mean(numeric_only=True)
# Out:
#                   HourlyRate        Age
# EducationField
# Human Resources    60.888889  37.037037
# Life Sciences      66.831683  37.107261
# Marketing          66.150943  37.924528
# Medical            65.280172  36.838362
# Other              62.365854  35.365854
# Technical Degree   66.621212  36.121212

# %%
dfgf = df.groupby(["JobRole"]).agg({"Age":[np.mean,np.std], "HourlyRate":[np.mean,"count"], "Education":'nunique'})
dfgf
# Out:
#                                  Age           HourlyRate       Education
#                                 mean       std       mean count   nunique
# JobRole
# Healthcare Representative  39.809160  8.200483  66.839695   131         5
# Human Resources            35.500000  7.937254  64.173077    52         5
# Laboratory Technician      34.096525  8.419382  66.683398   259         5
# Manager                    46.764706  6.941305  66.833333   102         5
# Manufacturing Director     38.296552  8.622584  65.006897   145         5
# Research Director          44.000000  7.923687  63.762500    80         5
# Research Scientist         34.236301  8.592472  66.708904   292         5
# Sales Executive            36.889571  8.092546  65.438650   326         5
# Sales Representative       30.361446  8.513373  64.337349    83         4

# %% [markdown]
# ### **Conditional Selection**

# %%
df.loc[df["Attrition"]=="Yes"]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
data(df)
# Out:
# ------------Column---------------
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
# ------------info---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ...

# %%
df.loc[(df.Department == "Research & Development") & (df.Education== 1)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 12     31        No      Travel_Rarely        670  Research & Development
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1402   31        No      Travel_Rarely       1276  Research & Development
# 1413   25        No      Travel_Rarely        977  Research & Development
# 1421   47        No         Non-Travel       1162  Research & Development
# 1429   39        No      Travel_Rarely        116  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[(df.EducationField.isin (["Life Sciences","Medical"]))]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df["random"] = np.random.rand()
df['random']
# Out:
# 0       0.405534
# 1       0.405534
# 2       0.405534
# 3       0.405534
# 4       0.405534
#           ...
# 1465    0.405534
# 1466    0.405534
# 1467    0.405534
# 1468    0.405534
# 1469    0.405534
# Name: random, Length: 1470, dtype: float64
